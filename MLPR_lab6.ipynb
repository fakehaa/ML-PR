# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\fakeh\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\fakeh\anaconda3\lib\site-packages (from opencv-python) (1.24.3)

# %%
# !pip install ultralytics --ignore-installed
# Out:
# Collecting ultralytics
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/20/59/d3d2b765881df375c006bb818547fed9aaa7d7b017b44663c31a1f443389/ultralytics-8.2.19-py3-none-any.whl.metadata
#   Using cached ultralytics-8.2.19-py3-none-any.whl.metadata (40 kB)
# Collecting matplotlib>=3.3.0 (from ultralytics)
#   Obtaining dependency information for matplotlib>=3.3.0 from https://files.pythonhosted.org/packages/c6/c8/6936e8c7b279a5abac82f399d8d72ac25da530cf5f78a0e40063e492558c/matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting pillow>=7.1.2 (from ultralytics)
#   Obtaining dependency information for pillow>=7.1.2 from https://files.pythonhosted.org/packages/0a/16/c83877524c47976f16703d2e05c363244bc1e60ab439e078b3cd046d07db/pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Obtaining dependency information for pyyaml>=5.3.1 from https://files.pythonhosted.org/packages/b3/34/65bb4b2d7908044963ebf614fe0fdb080773fc7030d7e39c8d3eddcd4257/PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Obtaining dependency information for requests>=2.23.0 from https://files.pythonhosted.org/packages/c3/20/748e38b466e0819491f0ce6e90ebe4184966ee304fe483e2c414b0f4ef07/requests-2.32.2-py3-none-any.whl.metadata
#   Downloading requests-2.32.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Obtaining dependency information for scipy>=1.4.1 from https://files.pythonhosted.org/packages/4a/48/4513a1a5623a23e95f94abd675ed91cfb19989c58e9f6f7d03990f6caf3d/scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.6 kB 1.3 MB/s eta 0:00:01
#      -------------------- ------------------- 30.7/60.6 kB 1.3 MB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.6 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 402.7 kB/s eta 0:00:00
# Collecting torch>=1.8.0 (from ultralytics)
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/2a/b7/a3cf5fd40334b9785cc83ee0c96b50603026eb3aa70210a33729018e7029/torch-2.3.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Obtaining dependency information for torchvision>=0.9.0 from https://files.pythonhosted.org/packages/12/c2/7c89c62f2b0a606070aa7cdb8af8af0c905562942778ebdd77600642c3b9/torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata
#   Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting tqdm>=4.64.0 (from ultralytics)
#   Obtaining dependency information for tqdm>=4.64.0 from https://files.pythonhosted.org/packages/18/eb/fdb7eb9e48b7b02554e1664afd3bd3f117f6b6d6c5881438a0b055554f9b/tqdm-4.66.4-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.5 MB/s eta 0:00:00
# Collecting psutil (from ultralytics)
#   Obtaining dependency information for psutil from https://files.pythonhosted.org/packages/93/52/3e39d26feae7df0aa0fd510b14012c3678b36ed068f7d78b8d8784d61f0e/psutil-5.9.8-cp37-abi3-win_amd64.whl.metadata
#   Downloading psutil-5.9.8-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Collecting py-cpuinfo (from ultralytics)
#   Obtaining dependency information for py-cpuinfo from https://files.pythonhosted.org/packages/e0/a9/023730ba63db1e494a271cb018dcd361bd2c917ba7004c3e49d5daf795a2/py_cpuinfo-9.0.0-py3-none-any.whl.metadata
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting thop>=0.1.1 (from ultralytics)
#   Obtaining dependency information for thop>=0.1.1 from https://files.pythonhosted.org/packages/bb/0f/72beeab4ff5221dc47127c80f8834b4bcd0cb36f6ba91c0b1d04a1233403/thop-0.1.1.post2209072238-py3-none-any.whl.metadata
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting pandas>=1.1.4 (from ultralytics)
#   Obtaining dependency information for pandas>=1.1.4 from https://files.pythonhosted.org/packages/ab/63/966db1321a0ad55df1d1fe51505d2cdae191b84c907974873817b0a6e849/pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Obtaining dependency information for seaborn>=0.11.0 from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/d6/4f/76d0dd0bca417691918484c26c74dd9dd44fbf528bbfeb30d754886e2c54/contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/c5/d4/f426fa1ca42e47bcfff0c878fa9d49d9c03379d00903a7c178f95b97867a/fonttools-4.51.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading fonttools-4.51.0-cp311-cp311-win_amd64.whl.metadata (162 kB)
#      ---------------------------------------- 0.0/162.8 kB ? eta -:--:--
#      ------------------- ------------------- 81.9/162.8 kB 2.3 MB/s eta 0:00:01
#      -------------------------- ----------- 112.6/162.8 kB 2.2 MB/s eta 0:00:01
#      ----------------------------- ------ 133.1/162.8 kB 983.0 kB/s eta 0:00:01
#      -------------------------------------- 162.8/162.8 kB 1.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/1e/37/d3c2d4ba2719059a0f12730947bbe1ad5ee8bff89e8c35319dcb2c9ddb4c/kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting numpy>=1.23 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for numpy>=1.23 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting packaging>=20.0 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for packaging>=20.0 from https://files.pythonhosted.org/packages/49/df/1fceb2f8900f8639e278b056416d49134fb8d84c5942ffaa01ad34782422/packaging-24.0-py3-none-any.whl.metadata
#   Downloading packaging-24.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting python-dateutil>=2.7 (from matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for python-dateutil>=2.7 from https://files.pythonhosted.org/packages/ec/57/56b9bcc3c9c6a792fcbaf139543cee77261f3651ca9da0c93f5c1221264b/python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=1.1.4->ultralytics)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.4->ultralytics)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/57/ec/80c8d48ac8b1741d5b963797b7c0c869335619e13d4744ca2f67fc11c6fc/charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl.metadata
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.23.0->ultralytics)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.23.0->ultralytics)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/41/24/0b023b6537dfc9bae2c779353998e3e99ac7dfff4222fc6126650e93c3f3/filelock-3.14.0-py3-none-any.whl.metadata
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions>=4.8.0 (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/01/f3/936e209267d6ef7510322191003885de524fc48d1b43269810cd589ceaf5/typing_extensions-4.11.0-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for sympy from https://files.pythonhosted.org/packages/d2/05/e6600db80270777c4a64238a98d442f0fd07cc8915be2a1c16da7f2b9e74/sympy-1.12-py3-none-any.whl.metadata
#   Downloading sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for networkx from https://files.pythonhosted.org/packages/38/e9/5f72929373e1a0e8d142a130f3f97e6ff920070f87f91c4e13e40e0fba5a/networkx-3.3-py3-none-any.whl.metadata
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for jinja2 from https://files.pythonhosted.org/packages/31/80/3a54838c3fb461f6fec263ebf3a3a41771bd05190238de3486aae8540c36/jinja2-3.1.4-py3-none-any.whl.metadata
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/ba/a3/16e9fe32187e9c8bc7f9b7bcd9728529faa725231a0c96f2f98714ff2fc5/fsspec-2024.5.0-py3-none-any.whl.metadata
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting mkl<=2021.4.0,>=2021.1.1 (from torch>=1.8.0->ultralytics)
#   Obtaining dependency information for mkl<=2021.4.0,>=2021.1.1 from https://files.pythonhosted.org/packages/fe/1c/5f6dbf18e8b73e0a5472466f0ea8d48ce9efae39bd2ff38cebf8dce61259/mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting colorama (from tqdm>=4.64.0->ultralytics)
#   Obtaining dependency information for colorama from https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl.metadata
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting intel-openmp==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics)
#   Obtaining dependency information for intel-openmp==2021.* from https://files.pythonhosted.org/packages/6f/21/b590c0cc3888b24f2ac9898c41d852d7454a1695fbad34bee85dba6dc408/intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics)
#   Obtaining dependency information for six>=1.5 from https://files.pythonhosted.org/packages/d9/5a/e7c31adbe875f2abbb91bd84cf2dc52d792b5a01506781dbcf25c91daf11/six-1.16.0-py2.py3-none-any.whl.metadata
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/b7/a2/c78a06a9ec6d04b3445a949615c4c7ed86a0b2eb68e44e7541b9d57067cc/MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata
#   Downloading MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.8.0->ultralytics)
#   Obtaining dependency information for mpmath>=0.19 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached ultralytics-8.2.19-py3-none-any.whl (757 kB)
# Using cached matplotlib-3.9.0-cp311-cp311-win_amd64.whl (8.0 MB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
# Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
# Using cached requests-2.32.2-py3-none-any.whl (63 kB)
# Using cached scipy-1.13.1-cp311-cp311-win_amd64.whl (46.2 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached torch-2.3.0-cp311-cp311-win_amd64.whl (159.8 MB)
# Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl (1.2 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached psutil-5.9.8-cp37-abi3-win_amd64.whl (255 kB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-win_amd64.whl (99 kB)
# Using cached contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.51.0-cp311-cp311-win_amd64.whl (2.2 MB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Using cached packaging-24.0-py3-none-any.whl (53 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached fsspec-2024.5.0-py3-none-any.whl (316 kB)
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: tbb, pytz, py-cpuinfo, mpmath, intel-openmp, urllib3, tzdata, typing-extensions, sympy, six, pyyaml, pyparsing, psutil, pillow, packaging, numpy, networkx, mkl, MarkupSafe, kiwisolver, idna, fsspec, fonttools, filelock, cycler, colorama, charset-normalizer, certifi, tqdm, scipy, requests, python-dateutil, opencv-python, jinja2, contourpy, torch, pandas, matplotlib, torchvision, thop, seaborn, ultralytics
# Successfully installed MarkupSafe-2.1.1 certifi-2024.2.2 charset-normalizer-2.0.4 colorama-0.4.6 contourpy-1.0.5 cycler-0.11.0 filelock-3.14.0 fonttools-4.25.0 fsspec-2023.4.0 idna-3.4 intel-openmp-2021.4.0 jinja2-3.1.2 kiwisolver-1.4.4 matplotlib-3.7.2 mkl-2021.4.0 mpmath-1.3.0 networkx-3.1 numpy-1.24.3 opencv-python-4.9.0.80 packaging-23.1 pandas-2.0.3 pillow-10.3.0 psutil-5.9.0 py-cpuinfo-8.0.0 pyparsing-3.0.9 python-dateutil-2.8.2 pytz-2023.3.post1 pyyaml-6.0.1 requests-2.31.0 scipy-1.11.1 seaborn-0.12.2 six-1.16.0 sympy-1.11.1 tbb-0.2 thop-0.1.1.post2209072238 torch-2.3.0 torchvision-0.18.0 tqdm-4.65.0 typing-extensions-4.11.0 tzdata-2023.3 ultralytics-8.2.19 urllib3-1.26.16
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# botocore 1.29.76 requires urllib3<1.27,>=1.25.4, but you have urllib3 2.2.1 which is incompatible.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires python-dateutil==2.8.2, but you have python-dateutil 2.9.0.post0 which is incompatible.
# conda-repo-cli 1.0.75 requires requests==2.31.0, but you have requests 2.32.2 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# s3fs 2023.4.0 requires fsspec==2023.4.0, but you have fsspec 2024.5.0 which is incompatible.
# spyder 5.4.3 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.1 which is incompatible.

# %%
from ultralytics import YOLO
model = YOLO("yolo-Weights/yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolo-Weights\yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 8.86MB/s]

# %%
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat","traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",   
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat","baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli", 
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed", 
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone", 
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", 
              "teddy bear", "hair drier", "toothbrush" ]

# %%
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
# Out:
# True

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 persons, 1 chair, 84.5ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.42
# Class name --> person
# Speed: 4.5ms preprocess, 84.5ms inference, 1776.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 162.4ms
# Confidence ---> 0.88
# Class name --> laptop
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 4.2ms preprocess, 162.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 152.5ms
# Confidence ---> 0.88
# Class name --> laptop
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.0ms preprocess, 152.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 154.7ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.0ms preprocess, 154.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 165.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.0ms preprocess, 165.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 153.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 153.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 157.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.0ms preprocess, 157.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 166.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 166.9ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 151.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 2.0ms preprocess, 151.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 158.6ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 4.2ms preprocess, 158.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 141.2ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.4
# Class name --> chair
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 141.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 134.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 5.0ms preprocess, 134.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 155.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 3.0ms preprocess, 155.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 158.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.28
# Class name --> chair
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 158.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 171.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 2.0ms preprocess, 171.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 47.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 2.2ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 42.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.3ms preprocess, 42.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 46.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.0ms preprocess, 46.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 55.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 1.0ms preprocess, 55.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 48.1ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.29
# Class name --> chair
# Speed: 1.0ms preprocess, 48.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 51.5ms
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 51.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 1.1ms preprocess, 51.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 laptop, 50.6ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.51
# Class name --> chair
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 50.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 55.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 45.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 46.1ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.3ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 47.7ms
# Confidence ---> 0.88
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 47.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 45.3ms
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.0ms preprocess, 45.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 44.8ms
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 44.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 48.3ms
# Confidence ---> 0.9
# Class name --> laptop
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.2ms preprocess, 48.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 44.7ms
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 46.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.1ms preprocess, 46.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.7ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.0ms preprocess, 47.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 45.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.4ms preprocess, 45.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 48.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.0ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 48.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.1ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 50.9ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.3ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 51.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.2ms preprocess, 51.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.1ms
# Confidence ---> 0.93
# Class name --> laptop
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.0ms preprocess, 49.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 48.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.1ms preprocess, 48.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.1ms
# Confidence ---> 0.87
# Class name --> laptop
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.1ms preprocess, 49.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 1.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 49.4ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Speed: 1.3ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 47.6ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Speed: 1.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 49.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Speed: 1.5ms preprocess, 49.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 51.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.3ms preprocess, 51.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 45.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.4ms preprocess, 45.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.2ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.0ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 44.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 44.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 49.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 48.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.5ms preprocess, 48.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 58.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.1ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 47.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> laptop
# Speed: 1.0ms preprocess, 47.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 49.3ms
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 49.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 48.5ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.0ms preprocess, 48.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 49.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 46.5ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.0ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 50.0ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.7ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.0ms preprocess, 47.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.5ms
# Confidence ---> 0.87
# Class name --> laptop
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.1ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 51.2ms
# Confidence ---> 0.9
# Class name --> laptop
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.0ms preprocess, 51.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 50.6ms
# Confidence ---> 0.92
# Class name --> laptop
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.2ms preprocess, 50.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 50.4ms
# Confidence ---> 0.93
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 50.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 59.2ms
# Confidence ---> 0.93
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.4ms preprocess, 59.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 52.2ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.2ms preprocess, 52.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 50.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.0ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 54.4ms
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 49.9ms
# Confidence ---> 0.87
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.1ms preprocess, 49.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 52.0ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 52.0ms
# Confidence ---> 0.84
# Class name --> laptop
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 47.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.3ms preprocess, 47.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 50.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.5ms preprocess, 50.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 51.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 62.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.85
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Speed: 1.2ms preprocess, 62.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 chairs, 2 laptops, 52.2ms
# Confidence ---> 0.87
# Class name --> laptop
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.27
# Class name --> chair
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.0ms preprocess, 52.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 2 laptops, 50.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.59
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 1.0ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 52.9ms
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Speed: 1.0ms preprocess, 52.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 48.8ms
# Confidence ---> 0.92
# Class name --> laptop
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.0ms preprocess, 48.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 51.9ms
# Confidence ---> 0.91
# Class name --> laptop
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 51.8ms
# Confidence ---> 0.88
# Class name --> laptop
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 53.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 49.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Speed: 1.0ms preprocess, 49.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 60.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Speed: 1.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 48.2ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.0ms preprocess, 48.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 54.9ms
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.33
# Class name --> laptop
# Speed: 2.0ms preprocess, 54.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 50.5ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 1.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 48.9ms
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Speed: 1.0ms preprocess, 48.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 laptops, 51.0ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 1.0ms preprocess, 51.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 51.3ms
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 53.4ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.0ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 2 laptops, 62.9ms
# Confidence ---> 0.89
# Class name --> laptop
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 52.3ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 1.0ms preprocess, 52.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 50.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.4ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 51.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 50.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> chair
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.0ms preprocess, 50.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 53.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> chair
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.0ms preprocess, 53.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 chair, 1 laptop, 50.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 2.0ms preprocess, 50.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 59.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.0ms preprocess, 59.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 51.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Speed: 1.0ms preprocess, 51.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 55.1ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.2ms preprocess, 55.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 52.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 1 cell phone, 55.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.6ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 52.9ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.2ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 53.3ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.0ms preprocess, 53.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 65.4ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Speed: 2.0ms preprocess, 65.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 52.8ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Speed: 1.4ms preprocess, 52.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 49.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 1.0ms preprocess, 49.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 51.8ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Speed: 1.4ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 51.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.1ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 51.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 51.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 50.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.0ms preprocess, 50.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 66.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 54.5ms
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 1.3ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 56.0ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 laptops, 52.1ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 52.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 laptops, 51.7ms
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.0ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 53.6ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.0ms preprocess, 53.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 64.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.4ms preprocess, 64.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 52.8ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 1.0ms preprocess, 52.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 57.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.86
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.0ms preprocess, 57.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 55.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.83
# Class name --> laptop
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.1ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 51.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Speed: 1.0ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 56.4ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 56.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 laptops, 60.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.54
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 1.0ms preprocess, 60.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 laptops, 55.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.56
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.0ms preprocess, 55.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 1 laptop, 55.4ms
# Confidence ---> 0.9
# Class name --> laptop
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.3
# Class name --> chair
# Speed: 1.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 laptop, 53.2ms
# Confidence ---> 0.79
# Class name --> laptop
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 53.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 bottle, 1 laptop, 53.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.3ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 59.2ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 1.5ms preprocess, 59.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 74.9ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.55
# Class name --> person
# ...
# Class name --> person
# Speed: 2.0ms preprocess, 63.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 62.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Confidence ---> 0.58
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 62.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 2.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 laptop, 1 cell phone, 63.3ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Speed: 2.0ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 68.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 laptops, 66.9ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.35
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 66.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 65.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.0ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 63.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.63
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.32
# Class name --> laptop
# Speed: 2.0ms preprocess, 63.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 63.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.32
# Class name --> laptop
# Speed: 2.0ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 65.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.0ms preprocess, 65.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 65.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> person
# Speed: 1.0ms preprocess, 65.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 65.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> chair
# Speed: 2.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 69.9ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.56
# Class name --> chair
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 2.0ms preprocess, 69.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 73.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.49
# Class name --> chair
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 66.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.48
# Class name --> chair
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.26
# Class name --> laptop
# Speed: 2.0ms preprocess, 66.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 67.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.52
# Class name --> chair
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 67.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.6
# Class name --> chair
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.26
# Class name --> chair
# Speed: 2.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 67.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> chair
# Confidence ---> 0.37
# Class name --> laptop
# Speed: 2.0ms preprocess, 67.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 72.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> chair
# Speed: 1.0ms preprocess, 72.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 61.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Speed: 2.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 67.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> chair
# Speed: 2.0ms preprocess, 67.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 70.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.26
# Class name --> chair
# Speed: 2.0ms preprocess, 70.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 laptops, 68.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.34
# Class name --> laptop
# Confidence ---> 0.32
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> chair
# Speed: 2.0ms preprocess, 68.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 laptops, 65.6ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> chair
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 laptops, 62.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 62.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 65.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.0ms preprocess, 65.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 2 laptops, 60.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.44
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 2 laptops, 66.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.31
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> chair
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 66.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 67.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.0ms preprocess, 67.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 69.6ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 tv, 2 laptops, 67.5ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 laptop, 67.3ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.36
# Class name --> chair
# Speed: 1.0ms preprocess, 67.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 71.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.45
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> laptop
# Speed: 1.0ms preprocess, 71.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 laptops, 66.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.43
# Class name --> laptop
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 2.0ms preprocess, 66.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 2 laptops, 69.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
